# %%
import numpy as np

import pandas as pd

import matplotlib.pyplot as plt

# %matplotlib inline

import seaborn as sns

# %%
# Import dataset
emp_df=pd.read_excel("train.xlsx",index_col=0)

# %%
emp_df_test=pd.read_excel("test.xlsx",index_col=0)

# %%
emp_df
# Out:
#                     department     region         education gender  \
# employee_id
# 65438.0      Sales & Marketing   region_7  Master's & above      f
# 65141.0             Operations  region_22        Bachelor's      m
# 7513.0       Sales & Marketing  region_19        Bachelor's      m
# 2542.0       Sales & Marketing  region_23        Bachelor's      m
# 48945.0             Technology  region_26        Bachelor's      m
# ...                        ...        ...               ...    ...
# 3030.0              Technology  region_14        Bachelor's      m
# 74592.0             Operations  region_27  Master's & above      f
# 13918.0              Analytics   region_1        Bachelor's      m
# 13614.0      Sales & Marketing   region_9               NaN      m
# 51526.0                     HR  region_22        Bachelor's      m
#
#             recruitment_channel  no_of_trainings   age  previous_year_rating  \
# employee_id
# ...

# %%
emp_df.count()
# Out:
# department              54808
# region                  54808
# education               52399
# gender                  54808
# recruitment_channel     54808
# no_of_trainings         54808
# age                     54808
# previous_year_rating    50684
# length_of_service       54808
# KPIs_met >80%           54808
# awards_won?             54808
# avg_training_score      54808
# is_promoted             54808
# dtype: int64

# %%
emp_df_test.count()
# Out:
# department              23490
# region                  23490
# education               22456
# gender                  23490
# recruitment_channel     23490
# no_of_trainings         23490
# age                     23490
# previous_year_rating    21678
# length_of_service       23490
# KPIs_met >80%           23490
# awards_won?             23490
# avg_training_score      23490
# dtype: int64

# %%
emp_df.describe()
# Out:
#        no_of_trainings           age  previous_year_rating  length_of_service  \
# count     54808.000000  54808.000000          50684.000000       54808.000000
# mean          1.253011     34.803915              3.329256           5.865512
# std           0.609264      7.660169              1.259993           4.265094
# min           1.000000     20.000000              1.000000           1.000000
# 25%           1.000000     29.000000              3.000000           3.000000
# 50%           1.000000     33.000000              3.000000           5.000000
# 75%           1.000000     39.000000              4.000000           7.000000
# max          10.000000     60.000000              5.000000          37.000000
#
#        KPIs_met >80%   awards_won?  avg_training_score   is_promoted
# count   54808.000000  54808.000000        54808.000000  54808.000000
# mean        0.351974      0.023172           63.386750      0.085170
# ...

# %%
emp_df_test.describe()
# Out:
#        no_of_trainings           age  previous_year_rating  length_of_service  \
# count     23490.000000  23490.000000          21678.000000       23490.000000
# mean          1.254236     34.782929              3.339146           5.810387
# std           0.600910      7.679492              1.263294           4.207917
# min           1.000000     20.000000              1.000000           1.000000
# 25%           1.000000     29.000000              3.000000           3.000000
# 50%           1.000000     33.000000              3.000000           5.000000
# 75%           1.000000     39.000000              4.000000           7.000000
# max           9.000000     60.000000              5.000000          34.000000
#
#        KPIs_met >80%   awards_won?  avg_training_score
# count   23490.000000  23490.000000        23490.000000
# mean        0.358834      0.022776           63.263133
# std         0.479668      0.149191           13.411750
# ...

# %%
emp_df.describe(include=['object'])
# Out:
#                department    region   education gender recruitment_channel
# count               54808     54808       52399  54808               54808
# unique                  9        34           3      2                   3
# top     Sales & Marketing  region_2  Bachelor's      m               other
# freq                16840     12343       36669  38496               30446

# %%
emp_df_test.describe(include=['object'])
# Out:
#                department    region   education gender recruitment_channel
# count               23490     23490       22456  23490               23490
# unique                  9        34           3      2                   3
# top     Sales & Marketing  region_2  Bachelor's      m               other
# freq                 7315      5299       15578  16596               13078

# %%
emp_df.isnull().sum()
# Out:
# department                 0
# region                     0
# education               2409
# gender                     0
# recruitment_channel        0
# no_of_trainings            0
# age                        0
# previous_year_rating    4124
# length_of_service          0
# KPIs_met >80%              0
# awards_won?                0
# avg_training_score         0
# is_promoted                0
# dtype: int64

# %%
emp_df_test.isnull().sum()
# Out:
# department                 0
# region                     0
# education               1034
# gender                     0
# recruitment_channel        0
# no_of_trainings            0
# age                        0
# previous_year_rating    1812
# length_of_service          0
# KPIs_met >80%              0
# awards_won?                0
# avg_training_score         0
# dtype: int64

# %%
from sklearn.metrics import mean_squared_error
from sklearn.impute import SimpleImputer

# %% [markdown]
# Using imputers of SKLearn to replace missing values
#
# 1.Mean for numerical and
#
# 2.Mode for frequency

# %%
mean_imputer = SimpleImputer(missing_values=np.nan, strategy='mean')

mode_imputer = SimpleImputer(missing_values=np.nan, strategy='most_frequent')

# %%
emp_df['previous_year_rating'] = mean_imputer.fit_transform(emp_df['previous_year_rating'].values.reshape(-1,1))[:,0]

# %%
mymap = {"Bachelor's":2, "Below Secondary":1, "Master's & above":3}
emp_df=emp_df.applymap(lambda s: mymap.get(s) if s in mymap else s)

# %%
emp_df_test['previous_year_rating'] = mean_imputer.fit_transform(emp_df_test['previous_year_rating'].values.reshape(-1,1))[:,0]
mymap = {"Bachelor's":2, "Below Secondary":1, "Master's & above":3}
emp_df_test=emp_df_test.applymap(lambda s: mymap.get(s) if s in mymap else s)

# %%
emp_df.isnull().sum()
# Out:
# department                 0
# region                     0
# education               2409
# gender                     0
# recruitment_channel        0
# no_of_trainings            0
# age                        0
# previous_year_rating       0
# length_of_service          0
# KPIs_met >80%              0
# awards_won?                0
# avg_training_score         0
# is_promoted                0
# dtype: int64

# %%
emp_df_test.isnull().sum()
# Out:
# department                 0
# region                     0
# education               1034
# gender                     0
# recruitment_channel        0
# no_of_trainings            0
# age                        0
# previous_year_rating       0
# length_of_service          0
# KPIs_met >80%              0
# awards_won?                0
# avg_training_score         0
# dtype: int64

# %%
emp_df['education'] = mode_imputer.fit_transform(emp_df['education'].values.reshape(-1,1))[:,0]
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/impute.py:341: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   row_mask = np.logical_not(row_mask).astype(np.bool)

# %%
emp_df_test['education'] = mode_imputer.fit_transform(emp_df_test['education'].values.reshape(-1,1))[:,0]
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/impute.py:341: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   row_mask = np.logical_not(row_mask).astype(np.bool)

# %%
emp_df
# Out:
#                     department     region  education gender  \
# employee_id
# 65438.0      Sales & Marketing   region_7        3.0      f
# 65141.0             Operations  region_22        2.0      m
# 7513.0       Sales & Marketing  region_19        2.0      m
# 2542.0       Sales & Marketing  region_23        2.0      m
# 48945.0             Technology  region_26        2.0      m
# ...                        ...        ...        ...    ...
# 3030.0              Technology  region_14        2.0      m
# 74592.0             Operations  region_27        3.0      f
# 13918.0              Analytics   region_1        2.0      m
# 13614.0      Sales & Marketing   region_9        2.0      m
# 51526.0                     HR  region_22        2.0      m
#
#             recruitment_channel  no_of_trainings   age  previous_year_rating  \
# employee_id
# 65438.0                sourcing              1.0  35.0                   5.0
# ...

# %%
emp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 54808 entries, 65438.0 to 51526.0
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   department            54808 non-null  object
#  1   region                54808 non-null  object
#  2   education             54808 non-null  float64
#  3   gender                54808 non-null  object
#  4   recruitment_channel   54808 non-null  object
#  5   no_of_trainings       54808 non-null  float64
#  6   age                   54808 non-null  float64
#  7   previous_year_rating  54808 non-null  float64
#  8   length_of_service     54808 non-null  float64
#  9   KPIs_met >80%         54808 non-null  float64
#  10  awards_won?           54808 non-null  float64
#  11  avg_training_score    54808 non-null  float64
#  12  is_promoted           54808 non-null  float64
# dtypes: float64(9), object(4)
# memory usage: 5.9+ MB

# %%
emp_df.isnull().sum()
# Out:
# department              0
# region                  0
# education               0
# gender                  0
# recruitment_channel     0
# no_of_trainings         0
# age                     0
# previous_year_rating    0
# length_of_service       0
# KPIs_met >80%           0
# awards_won?             0
# avg_training_score      0
# is_promoted             0
# dtype: int64

# %%
emp_df_test.isnull().sum()
# Out:
# department              0
# region                  0
# education               0
# gender                  0
# recruitment_channel     0
# no_of_trainings         0
# age                     0
# previous_year_rating    0
# length_of_service       0
# KPIs_met >80%           0
# awards_won?             0
# avg_training_score      0
# dtype: int64

# %%
plt.plot(emp_df['previous_year_rating'], emp_df['KPIs_met >80%'])
plt.title(" previous_year_rating vs KPIs_met >80%", fontsize = 10)
plt.xlabel("KPIs_met >80%")
plt.ylabel("previous_year_rating")
plt.show()

# %%
plt.figure(figsize=(25,15))
plt.bar(x = emp_df['awards_won?'], height = emp_df['length_of_service'], width = 1.5, color = 'deeppink')
plt.title("", fontsize = 10)
plt.xlabel('awards_won?')
plt.ylabel("length_of_service")
plt.show()

# %%
plt.figure(figsize=(20,15))
plt.hist(emp_df['avg_training_score'],  bins = 2, color = 'darkviolet')
plt.title("Histogram Plot", fontsize = 10)
plt.xlabel("'no_of_trainings")
plt.ylabel("Frequency in Range")
plt.show()

# %%
plt.style.use('ggplot')
plt.figure(figsize=(13,8))
plt.scatter(x = emp_df['length_of_service'], y = emp_df['avg_training_score'], c = 'r', marker='^', label = 'avg_training_score')
plt.scatter(x = emp_df['length_of_service'], y = emp_df['previous_year_rating'], c = 'b', marker = 'o', label = 'previous_year_rating')
plt.title("Scatter Plot", fontsize = 10)
plt.xlabel("length_of_service")
plt.ylabel("previous_year_rating")
plt.legend()
plt.show()

# %%
d = emp_df
d
# Out:
#                     department     region  education gender  \
# employee_id
# 65438.0      Sales & Marketing   region_7        3.0      f
# 65141.0             Operations  region_22        2.0      m
# 7513.0       Sales & Marketing  region_19        2.0      m
# 2542.0       Sales & Marketing  region_23        2.0      m
# 48945.0             Technology  region_26        2.0      m
# ...                        ...        ...        ...    ...
# 3030.0              Technology  region_14        2.0      m
# 74592.0             Operations  region_27        3.0      f
# 13918.0              Analytics   region_1        2.0      m
# 13614.0      Sales & Marketing   region_9        2.0      m
# 51526.0                     HR  region_22        2.0      m
#
#             recruitment_channel  no_of_trainings   age  previous_year_rating  \
# employee_id
# 65438.0                sourcing              1.0  35.0                   5.0
# ...

# %%
d.drop(['department','region','gender','recruitment_channel'], axis=1, inplace=True)
mymap = {"Bachelor's":2, "Below Secondary":1, "Master's & above":3}
d= d.applymap(lambda s: mymap.get(s) if s in mymap else s)
sns.distplot(d, kde=True, color="m")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
d_test = emp_df_test
d_test
# Out:
#                     department     region  education gender  \
# employee_id
# 8724.0              Technology  region_26        2.0      m
# 74430.0                     HR   region_4        2.0      f
# 72255.0      Sales & Marketing  region_13        2.0      m
# 38562.0            Procurement   region_2        2.0      f
# 64486.0                Finance  region_29        2.0      m
# ...                        ...        ...        ...    ...
# 53478.0                  Legal   region_2        1.0      m
# 25600.0             Technology  region_25        2.0      m
# 45409.0                     HR  region_16        2.0      f
# 1186.0             Procurement  region_31        2.0      m
# 5973.0              Technology  region_17        3.0      m
#
#             recruitment_channel  no_of_trainings   age  previous_year_rating  \
# employee_id
# 8724.0                 sourcing              1.0  24.0              3.339146
# ...

# %%
d_test.drop(['department','region','gender','recruitment_channel'], axis=1, inplace=True)
mymap = {"Bachelor's":2, "Below Secondary":1, "Master's & above":3}
d_test= d_test.applymap(lambda s: mymap.get(s) if s in mymap else s)
sns.distplot(d_test, kde=True, color="m")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
d
# Out:
#              education  no_of_trainings   age  previous_year_rating  \
# employee_id
# 65438.0            3.0              1.0  35.0                   5.0
# 65141.0            2.0              1.0  30.0                   5.0
# 7513.0             2.0              1.0  34.0                   3.0
# 2542.0             2.0              2.0  39.0                   1.0
# 48945.0            2.0              1.0  45.0                   3.0
# ...                ...              ...   ...                   ...
# 3030.0             2.0              1.0  48.0                   3.0
# 74592.0            3.0              1.0  37.0                   2.0
# 13918.0            2.0              1.0  27.0                   5.0
# 13614.0            2.0              1.0  29.0                   1.0
# 51526.0            2.0              1.0  27.0                   1.0
#
#              length_of_service  KPIs_met >80%  awards_won?  \
# employee_id
# 65438.0                    8.0            1.0          0.0
# ...

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation

# %%
feature_cols = ['education','no_of_trainings','age',	'previous_year_rating',	'length_of_service',	'KPIs_met >80%'	,'awards_won?',	'avg_training_score']
X = d[feature_cols] # Features
y = d.is_promoted # Target variable

# %%
feature_cols = ['education','no_of_trainings','age',	'previous_year_rating',	'length_of_service',	'KPIs_met >80%'	,'awards_won?',	'avg_training_score']
X1_test = d_test[feature_cols] # Features

# %%
# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1) # 70% training and 30% test

# %%
clf = DecisionTreeClassifier()

# Train Decision Tree Classifer
clf = clf.fit(X,y)

#Predict the response for test dataset
y_pred = clf.predict(X_test)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/tree/tree.py:149: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   y_encoded = np.zeros(y.shape, dtype=np.int)

# %%
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9809037280301648

# %%
pip install --upgrade scikit-learn==0.20.3
# Out:
# ...
#      |████████████████████████████████| 5.4 MB 4.8 MB/s
# ...
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.0.2
#     Uninstalling scikit-learn-1.0.2:
#       Successfully uninstalled scikit-learn-1.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# yellowbrick 1.4 requires scikit-learn>=1.0.0, but you have scikit-learn 0.20.3 which is incompatible.
# imbalanced-learn 0.8.1 requires scikit-learn>=0.24, but you have scikit-learn 0.20.3 which is incompatible.
# ...

# %%
# !pip install pydotplus

# %%
from sklearn.tree import export_graphviz
from sklearn.externals.six import StringIO  
from sklearn import tree
import pydotplus
import pydot
from IPython.display import Image

dot_data = StringIO()
tree.export_graphviz(clf, out_file=dot_data)
import pydotplus

graph = pydotplus.graphviz.graph_from_dot_data(dot_data.getvalue())

Image(graph.create_png())
# Out:
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.10061 to fit
